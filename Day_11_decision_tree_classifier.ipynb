# %%
import pandas as pd #For reading the dataset and to perform framing functions if needed
import numpy as np  #linear algebra function
import matplotlib.pyplot as plt #for visualizing the data
import seaborn as sns #for data visualization & distribution

# %%
weather_data=pd.read_csv('/content/weather_data.csv')

# %%
weather_data.head()
# Out:
#     Outlook Temperature Humidity    Wind Play
# 0     Sunny         Hot     High    Weak   No
# 1     Sunny         Hot     High  Strong   No
# 2  Overcast         Hot     High    Weak  Yes
# 3      Rain        Cool   Normal    Weak  Yes
# 4      Rain        Cool   Normal  Strong   No

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Outlook      14 non-null     object
#  1   Temperature  14 non-null     object
#  2   Humidity     14 non-null     object
#  3   Wind         14 non-null     object
#  4   Play         14 non-null     object
# dtypes: object(5)
# memory usage: 692.0+ bytes

# %%
weather_data.isnull().sum()
# Out:
# Outlook        0
# Temperature    0
# Humidity       0
# Wind           0
# Play           0
# dtype: int64

# %%
weather_data.shape
# Out:
# (14, 5)

# %%
weather_data.nunique()
# Out:
# Outlook        3
# Temperature    3
# Humidity       2
# Wind           2
# Play           2
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_encode=LabelEncoder()

# %%
weather_data['Outlook_encode']=label_encode.fit_transform(weather_data['Outlook'])
weather_data['Temperature_encode']=label_encode.fit_transform(weather_data['Temperature'])
weather_data['Humidity_encode']=label_encode.fit_transform(weather_data['Humidity'])
weather_data['Wind_encode']=label_encode.fit_transform(weather_data['Wind'])

# %%
weather_data['Outlook_encode']
# Out:
# 0     2
# 1     2
# 2     0
# 3     1
# 4     1
# 5     2
# 6     2
# 7     1
# 8     2
# 9     0
# 10    0
# 11    1
# 12    0
# 13    1
# Name: Outlook_encode, dtype: int64

# %%
x=weather_data[['Outlook_encode','Temperature_encode','Humidity_encode','Wind_encode']]
x.head(14)
# Out:
#     Outlook_encode  Temperature_encode  Humidity_encode  Wind_encode
# 0                2                   1                0            1
# 1                2                   1                0            0
# 2                0                   1                0            1
# 3                1                   0                1            1
# 4                1                   0                1            0
# 5                2                   2                0            1
# 6                2                   0                1            1
# 7                1                   2                1            1
# 8                2                   2                1            0
# 9                0                   2                0            0
# 10               0                   1                1            1
# 11               1                   2                0            0
# 12               0                   0                1            0
# 13               1                   2                0            1

# %%
y=weather_data.Play
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3    Yes
# 4     No
# Name: Play, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
weather_data
# Out:
#      Outlook Temperature Humidity    Wind Play  Outlook_encode  \
# 0      Sunny         Hot     High    Weak   No               2
# 1      Sunny         Hot     High  Strong   No               2
# 2   Overcast         Hot     High    Weak  Yes               0
# 3       Rain        Cool   Normal    Weak  Yes               1
# 4       Rain        Cool   Normal  Strong   No               1
# 5      Sunny        Mild     High    Weak   No               2
# 6      Sunny        Cool   Normal    Weak  Yes               2
# 7       Rain        Mild   Normal    Weak  Yes               1
# 8      Sunny        Mild   Normal  Strong  Yes               2
# 9   Overcast        Mild     High  Strong  Yes               0
# 10  Overcast         Hot   Normal    Weak  Yes               0
# 11      Rain        Mild     High  Strong   No               1
# 12  Overcast        Cool   Normal  Strong  Yes               0
# 13      Rain        Mild     High    Weak  Yes               1
#
#     Temperature_encode  Humidity_encode  Wind_encode
# 0                    1                0            1
# 1                    1                0            0
# 2                    1                0            1
# 3                    0                1            1
# 4                    0                1            0
# 5                    2                0            1
# 6                    0                1            1
# 7                    2                1            1
# 8                    2                1            0
# 9                    2                0            0
# 10                   1                1            1
# 11                   2                0            0
# 12                   0                1            0
# 13                   2                0            1

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
#from sklearn.model_selection import GridSearchCV
tree=DecisionTreeClassifier(criterion='gini',splitter='best')
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predict=tree.predict(x_train)
predict.flatten()
# Out:
# array(['No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes'], dtype=object)

# %%
from sklearn import metrics
report =metrics.classification_report(y_train,predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           No       1.00      1.00      1.00         3
#          Yes       1.00      1.00      1.00         8
#
#     accuracy                           1.00        11
#    macro avg       1.00      1.00      1.00        11
# weighted avg       1.00      1.00      1.00        11

# %%
plt.figure(figsize=(20,10))
plot_tree(tree,feature_names=['Outlook_encode','Temperature_encode','Humidity_encode','Wind_encode'],class_names=['No','Yes'],filled=True,fontsize=12)
plt.show()

# %%
plt.figure(figsize=(20,10))
plot_tree(tree,feature_names=['Outlook_encode','Temperature_encode','Humidity_encode','Wind_encode'],class_names=['No','Yes'],filled=True,fontsize=12)
plt.show()
