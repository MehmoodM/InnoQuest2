# %%
x=1.8
y= 1.3

# %%
round(x)
# Out:
# 2

# %%
round(y)
# Out:
# 1

# %%
x = 'Deep Learning'

# %%
x[5]
# Out:
# 'L'

# %%
x[5:]
# Out:
# 'Learning'

# %%
x[-8]
# Out:
# 'L'

# %%
x[-1]
# Out:
# 'g'

# %%
x[-8:-2]
# Out:
# 'Learni'

# %%
5 == 5
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
x=10
y=25

if x >3 and y>13:
  print(x)
if x<=3 or y>=13:
  print('second if')
# Out:
# 10
# second if

# %%
if x<=3 or y<=13:
  print(x)
else:

  print('else')
# Out:
# else

# %%
if x<=3 or y<=13:
  print(x)
elif x>3:
  print('elif')
else:

  print('else')
# Out:
# elif

# %%
if True:
  print('if')
# Out:
# if

# %%
if False:
  print('yes')

# %% [markdown]
# Function

# %%
def funct():
  print('yes')

# %%
funct()
# Out:
# yes

# %%
def mul():
  y = 3*4
  return y
mul()
# Out:
# 12

# %%
def multi(x):
  z = x*x
  return z
multi(4)
# Out:
# 16

# %%
def multi(x):
  z = x*5
  return z
multi(4)
# Out:
# 20

# %%
max(2, 44, -6)
# Out:
# 44

# %%
min(2,33,-6)
# Out:
# -6

# %%
abs(-5)
# Out:
# 5

# %%
abs(5)
# Out:
# 5

# %%
abs(-33)
# Out:
# 33

# %%
abs(-3*-3)
# Out:
# 9

# %% [markdown]
# List

# %%
ls = [3, 5.5, 'me']
ls
# Out:
# [3, 5.5, 'me']

# %%
ls[2]
# Out:
# 'me'

# %%
ls[1]
# Out:
# 5.5

# %%
ls[0:1]
# Out:
# [3]

# %%
ls[1:2]
# Out:
# [5.5]

# %%
ls[:2]
# Out:
# [3, 5.5]

# %%
ls[-1]
# Out:
# 'me'

# %%
ls.append(22)
ls
# Out:
# [3, 5.5, 'me', 22]

# %%
len(ls)
# Out:
# 4

# %% [markdown]
# Some Useful function

# %%
"'inno', 'isb', '40".split(',')
# Out:
# ["'inno'", " 'isb'", " '40"]

# %%
ls2 = [1,2,3,4,5]
sum(ls2)
# Out:
# 15

# %%
ls2.index(3)
# Out:
# 2

# %%
ls2.index(5)
# Out:
# 4

# %%
ls3= [ls,ls2]
ls3
# Out:
# [[3, 5.5, 'me', 22], [1, 2, 3, 4, 5]]

# %%
ls3[0]
# Out:
# [3, 5.5, 'me', 22]

# %%
ls3[1]
# Out:
# [1, 2, 3, 4, 5]

# %%
ls3[0][2]
# Out:
# 'me'

# %%
ls3[1][2]
# Out:
# 3

# %%
ls3[1][1]
# Out:
# 2

# %%
ls3[1][-2]
# Out:
# 4

# %%
ls2.sort()
ls2
# Out:
# [1, 2, 3, 4, 5]

# %%
ls.extend(ls2)
ls
# Out:
# [3, 5.5, 'me', 22, 1, 2, 3, 4, 5]

# %%
range(10)
# Out:
# range(0, 10)

# %%
t = (2,3,4,5)
t
# Out:
# (2, 3, 4, 5)

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# 5

# %% [markdown]
# Dictionary

# %%
xdict = {'house1' : '20k', 'house2' : '30k', 'house3' : '40k'}
xdict
# Out:
# {'house1': '20k', 'house2': '30k', 'house3': '40k'}

# %%
xdict['house1']
# Out:
# '20k'

# %%
xdict['house4'] = '50k'
xdict
# Out:
# {'house1': '20k', 'house2': '30k', 'house3': '40k', 'house4': '50k'}

# %%
xdict['another_dict'] = {'house1' : '200k', 'house2': '300k'}
xdict
# Out:
# {'house1': '20k',
#  'house2': '30k',
#  'house3': '40k',
#  'house4': '50k',
#  'another_dict': {'house1': '200k', 'house2': '300k'}}

# %% [markdown]
# Loop

# %%
for i in xdict:
  print(xdict[i])
# Out:
# 20k
# 30k
# 40k
# 50k
# {'house1': '200k', 'house2': '300k'}

# %%
x=0
while x<=5:
  print(x)
  x=x+1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
ls = [1,2,3,4]
ls1= [1,2,3,4]

for i in ls:
  for j in ls1:
    print(i*j)
# Out:
# 1
# 2
# 3
# 4
# 2
# 4
# 6
# 8
# 3
# 6
# 9
# 12
# 4
# 8
# 12
# 16

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
import math as m
m.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt
sqrt(25)
# Out:
# 5.0

# %%
from math import *
sqrt(25)
# Out:
# 5.0

# %%
floor(2.3)
# Out:
# 2

# %%
floor(2.7)
# Out:
# 2

# %%
...
multip
line
comment

...

# %% [markdown]
# Classes

# %%
class person:
  def __init__(self, name, age):
    self.name = name
    self.age = age
    def myfunc(self):
      print('hello myname is', self.name)
      print(f'hello ny age is: {self.age}')
      p1 = person('john', 22)
      p1.myfunc()
      print(p1.name)
      print(p1.age)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
class person():
  def __init__(self, name, age):
    self.name = name
    self.age = age
  def getname(self):
    print(f'my name is: {self.name}')
    print(f'my age is: {self.age}')
    print('my name is: ', self.name)
    print('my age is: ', self.age , 'qaidi no 804')

p2 = person('khan', '72')
p2.getname()
# Out:
# my name is: khan
# my age is: 72
# my name is:  khan
# my age is:  72 qaidi no 804
