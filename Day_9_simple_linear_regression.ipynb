# %%
import pandas as pd

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['Age'], df['Salary'], color='green')
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# <ipython-input-10-63d4fb902a4f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
plt.scatter(df['Years of Experience'], df['Salary'], color='green')

# %%
df['Years of Experience'].fillna(df['Years of Experience'].median(), inplace=True)
# Out:
# <ipython-input-13-0dc471a56b00>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Years of Experience'].fillna(df['Years of Experience'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    0
# Salary                 5
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# <ipython-input-17-90613879d37d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        3
# Job Title              2
# Years of Experience    0
# Salary                 5
# dtype: int64

# %%
sns.countplot(x='Education Level', data=df)
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %%
sns.countplot(x='Education Level', data=df, hue='Education Level')
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan, "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
df['Education Level'].fillna(df['Education Level'].mode()[0],inplace=True)
# Out:
# <ipython-input-22-66f113a48b6b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Education Level'].fillna(df['Education Level'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              2
# Years of Experience    0
# Salary                 5
# dtype: int64

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
ed_dictonary = {

"bachelor's": "Bachelor's",
"bachelor's degree": "Bachelor's",
"master's": "Master's",
"master's Degree": "Master's",
"phd": "PhD",
"phd": "PhD",
"high school": "High School"

}

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df['Education Level'] = df["Education Level"].str.lower().replace(ed_dictonary)

# %%
df["Education Level"].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "master's degree", 'High School'],
#       dtype=object)

# %%
sns.countplot(x='Education Level', data=df)
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %%
sns.countplot(x='Education Level', data=df, hue='Education Level')
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.dropna(subset='Salary', inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
df
# Out:
#        Age  Gender  Education Level              Job Title  \
# 0     32.0    Male       Bachelor's      Software Engineer
# 1     28.0  Female         Master's           Data Analyst
# 2     45.0    Male              PhD         Senior Manager
# 3     36.0  Female       Bachelor's        Sales Associate
# 4     52.0    Male         Master's               Director
# ...    ...     ...              ...                    ...
# 6699  49.0  Female              PhD  Director of Marketing
# 6700  32.0    Male      High School        Sales Associate
# 6701  30.0  Female       Bachelor's      Financial Manager
# 6702  46.0    Male  master's degree      Marketing Manager
# 6703  26.0  Female      High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
len(df['Job Title'].unique())
# Out:
# 192

# %%
df = df.drop('Job Title',axis=1)
df
# Out:
#        Age  Gender  Education Level  Years of Experience    Salary
# 0     32.0    Male       Bachelor's                  5.0   90000.0
# 1     28.0  Female         Master's                  3.0   65000.0
# 2     45.0    Male              PhD                 15.0  150000.0
# 3     36.0  Female       Bachelor's                  7.0   60000.0
# 4     52.0    Male         Master's                 20.0  200000.0
# ...    ...     ...              ...                  ...       ...
# 6699  49.0  Female              PhD                 20.0  200000.0
# 6700  32.0    Male      High School                  3.0   50000.0
# 6701  30.0  Female       Bachelor's                  4.0   55000.0
# 6702  46.0    Male  master's degree                 14.0  140000.0
# 6703  26.0  Female      High School                  1.0   35000.0
#
# [6699 rows x 5 columns]

# %%
df= pd.get_dummies(df, columns=df.select_dtypes(include=['object']).columns)

# %%
df.shape
# Out:
# (6699, 11)

# %%
df.dtypes
# Out:
# Age                                float64
# Years of Experience                float64
# Salary                             float64
# Gender_Female                         bool
# Gender_Male                           bool
# Gender_Other                          bool
# Education Level_Bachelor's            bool
# Education Level_High School           bool
# Education Level_Master's              bool
# Education Level_PhD                   bool
# Education Level_master's degree       bool
# dtype: object

# %%
df
# Out:
#        Age  Years of Experience    Salary  Gender_Female  Gender_Male  \
# 0     32.0                  5.0   90000.0          False         True
# 1     28.0                  3.0   65000.0           True        False
# 2     45.0                 15.0  150000.0          False         True
# 3     36.0                  7.0   60000.0           True        False
# 4     52.0                 20.0  200000.0          False         True
# ...    ...                  ...       ...            ...          ...
# 6699  49.0                 20.0  200000.0           True        False
# 6700  32.0                  3.0   50000.0          False         True
# 6701  30.0                  4.0   55000.0           True        False
# 6702  46.0                 14.0  140000.0          False         True
# 6703  26.0                  1.0   35000.0           True        False
#
#       Gender_Other  Education Level_Bachelor's  Education Level_High School  \
# ...

# %%
df = df.applymap(lambda x: 1 if x is True else (0 if x is False else x))
# Out:
# <ipython-input-42-406ee18cff86>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: 1 if x is True else (0 if x is False else x))

# %%
df
# Out:
#        Age  Years of Experience    Salary  Gender_Female  Gender_Male  \
# 0     32.0                  5.0   90000.0              0            1
# 1     28.0                  3.0   65000.0              1            0
# 2     45.0                 15.0  150000.0              0            1
# 3     36.0                  7.0   60000.0              1            0
# 4     52.0                 20.0  200000.0              0            1
# ...    ...                  ...       ...            ...          ...
# 6699  49.0                 20.0  200000.0              1            0
# 6700  32.0                  3.0   50000.0              0            1
# 6701  30.0                  4.0   55000.0              1            0
# 6702  46.0                 14.0  140000.0              0            1
# 6703  26.0                  1.0   35000.0              1            0
#
#       Gender_Other  Education Level_Bachelor's  Education Level_High School  \
# ...

# %%
y =  df['Salary']

# %%
y
# Out:
# 0        90000.0
# 1        65000.0
# 2       150000.0
# 3        60000.0
# 4       200000.0
#           ...
# 6699    200000.0
# 6700     50000.0
# 6701     55000.0
# 6702    140000.0
# 6703     35000.0
# Name: Salary, Length: 6699, dtype: float64

# %%
x = df.drop('Salary', axis=1)

# %%
x.head()
# Out:
#     Age  Years of Experience  Gender_Female  Gender_Male  Gender_Other  \
# 0  32.0                  5.0              0            1             0
# 1  28.0                  3.0              1            0             0
# 2  45.0                 15.0              0            1             0
# 3  36.0                  7.0              1            0             0
# 4  52.0                 20.0              0            1             0
#
#    Education Level_Bachelor's  Education Level_High School  \
# 0                           1                            0
# 1                           0                            0
# 2                           0                            0
# 3                           1                            0
# 4                           0                            0
#
#    Education Level_Master's  Education Level_PhD  \
# 0                         0                    0
# 1                         1                    0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (5359, 10)

# %%
len(x_train)
# Out:
# 5359

# %%
len(x_test)
# Out:
# 1340

# %%
corr_value = df.corrwith(df['Salary'])

# %%
corr_value
# Out:
# Age                                0.728053
# Years of Experience                0.808969
# Salary                             1.000000
# Gender_Female                     -0.127406
# Gender_Male                        0.126514
# Gender_Other                       0.009141
# Education Level_Bachelor's        -0.347676
# Education Level_High School       -0.398759
# Education Level_Master's           0.169766
# Education Level_PhD                0.483203
# Education Level_master's degree    0.102268
# dtype: float64

# %%
sortedvalue  = corr_value.sort_values(ascending=False)

# %%
sortedvalue
# Out:
# Salary                             1.000000
# Years of Experience                0.808969
# Age                                0.728053
# Education Level_PhD                0.483203
# Education Level_Master's           0.169766
# Gender_Male                        0.126514
# Education Level_master's degree    0.102268
# Gender_Other                       0.009141
# Gender_Female                     -0.127406
# Education Level_Bachelor's        -0.347676
# Education Level_High School       -0.398759
# dtype: float64

# %%
singleattribute  = x_train['Years of Experience']

# %%
singleattribute
# Out:
# 3861     3.0
# 4940     6.0
# 135     10.0
# 6574     6.0
# 3978     1.0
#         ...
# 3775    10.0
# 5194    12.0
# 5229     7.0
# 5394     8.0
# 862      2.0
# Name: Years of Experience, Length: 5359, dtype: float64

# %%
singleattribute.shape
# Out:
# (5359,)

# %%
singleattribute  = singleattribute.values.reshape(-1, 1)

# %%
singleattribute.shape
# Out:
# (5359, 1)

# %%
print(singleattribute)
# Out:
# [[ 3.]
#  [ 6.]
#  [10.]
#  ...
#  [ 7.]
#  [ 8.]
#  [ 2.]]

# %%
from sklearn.linear_model import LinearRegression

# %%
slr = LinearRegression()

# %%
y_train
# Out:
# 3861     50000.0
# 4940    105000.0
# 135      55000.0
# 6574     75000.0
# 3978     35000.0
#           ...
# 3775    110000.0
# 5194    150000.0
# 5229    120000.0
# 5394    120000.0
# 862     110000.0
# Name: Salary, Length: 5359, dtype: float64

# %%
y_train.shape
# Out:
# (5359,)

# %%
singleattribute
# Out:
# array([[ 3.],
#        [ 6.],
#        [10.],
#        ...,
#        [ 7.],
#        [ 8.],
#        [ 2.]])

# %%
singleattribute.shape
# Out:
# (5359, 1)

# %%
slr.fit(singleattribute, y_train)
# Out:
# LinearRegression()

# %%
model_prediction_train = slr.predict(singleattribute)

# %%
model_prediction_train
# Out:
# array([ 79526.19476772, 100654.29608708, 128825.09784623, ...,
#        107696.99652687, 114739.69696666,  72483.49432794])

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
print('mean squared error', mean_squared_error(y_train, model_prediction_train))

print('root mean squared error', mean_squared_error(y_train, model_prediction_train))

print('r2 score', r2_score(y_train, model_prediction_train))
# Out:
# mean squared error 966731516.9085451
# root mean squared error 966731516.9085451
# r2 score 0.6512059428025054

# %%
print('mean square error:', mean_squared_error(model_prediction_train, y_train))
print('mean absolute error:', mean_absolute_error(model_prediction_train, y_train))
print('r2 score:', r2_score(model_prediction_train, y_train))
# Out:
# mean square error: 966731516.9085451
# mean absolute error: 24944.31940705492
# r2 score: 0.4643874782585097

# %%
sinlgeatt = x_test['Years of Experience']

# %%
sinlgeatt
# Out:
# 2460     2.0
# 2230     8.0
# 5559     3.0
# 3080     2.0
# 265      1.5
#         ...
# 4658    12.0
# 2155    14.0
# 5375     1.0
# 4561     3.0
# 2831     0.0
# Name: Years of Experience, Length: 1340, dtype: float64

# %%
sinlgeatt = sinlgeatt.values.reshape(-1,1)

# %%
model_prediction_test = slr.predict(sinlgeatt)

# %%
model_prediction_test
# Out:
# array([ 72483.49432794, 114739.69696666,  79526.19476772, ...,
#         65440.79388815,  79526.19476772,  58398.09344836])

# %%
print('mean square error:', mean_squared_error(y_test,model_prediction_test))
print('mean absolute error:', mean_absolute_error(y_test,model_prediction_test))
print('r2 score:', r2_score(y_test,model_prediction_test))
# Out:
# mean square error: 946833177.7094355
# mean absolute error: 24722.101443221916
# r2 score: 0.6669549610495003

# %%
mlr= LinearRegression()

# %%
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
train_predict = mlr.predict(x_train)

# %%
print('mean square error:', mean_squared_error(y_train,train_predict))
print('mean absolute error:', mean_absolute_error(y_train,train_predict))
print('r2 score:', r2_score(y_train,train_predict))
# Out:
# mean square error: 755172115.4471005
# mean absolute error: 21606.246636776592
# r2 score: 0.7275359896494127

# %%
test_predict = mlr.predict(x_test)

# %%
print('mean square error:', mean_squared_error(y_test,test_predict))
print('mean absolute error:', mean_absolute_error(y_test,test_predict))
print('r2 score:', r2_score(y_test,test_predict))
# Out:
# mean square error: 734228417.5464185
# mean absolute error: 21014.136081517838
# r2 score: 0.7417378925061785

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
plr = PolynomialFeatures(degree=2)

x_trainp = plr.fit_transform(x_train)
x_testp = plr.fit_transform(x_test)

# %%
plrmodel = LinearRegression()

# %%
plrmodel.fit(x_trainp, y_train)
# Out:
# LinearRegression()

# %%
trainn= plrmodel.predict(x_trainp)

# %%
print('mean square error:', mean_squared_error(trainn, y_train))
print('mean absolute error:', mean_absolute_error(trainn, y_train))
print('r2 score:', r2_score(trainn, y_train))
# Out:
# mean square error: 496359419.4243154
# mean absolute error: 16983.688853601336
# r2 score: 0.7818469286621982

# %%
testn= plrmodel.predict(x_testp)

# %%
print('mean square error:', mean_squared_error(testn, y_test))
print('mean absolute error:', mean_absolute_error(testn, y_test))
print('r2 score:', r2_score(testn, y_test))
# Out:
# mean square error: 477072856.4321275
# mean absolute error: 16628.152606423366
# r2 score: 0.7991879254264646
